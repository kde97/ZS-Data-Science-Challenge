# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
df=pd.read_csv(r"C:\Users\User\Desktop\Cristano_Ronaldo_Final_v1\data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  match_event_id  location_x  location_y  remaining_min  \
# 0           0            10.0       167.0        72.0           10.0
# 1           1            12.0      -157.0         0.0           10.0
# 2           2            35.0      -101.0       135.0            7.0
# 3           3            43.0       138.0       175.0            6.0
# 4           4           155.0         0.0         0.0            NaN
#
#    power_of_shot  knockout_match game_season  remaining_sec  distance_of_shot  \
# 0            1.0             0.0     2000-01           27.0              38.0
# 1            1.0             0.0     2000-01           22.0              35.0
# 2            1.0             0.0     2000-01           45.0              36.0
# 3            1.0             0.0     2000-01           52.0              42.0
# 4            2.0             0.0     2000-01           19.0              20.0
#
#    is_goal           area_of_shot shot_basics    range_of_shot  \
# ...

# %%
pd.set_option('display.max_columns', None)
df=df.rename(columns={ df.columns[0]: "Index" })
df.head()
# Out:
#    Index  match_event_id  location_x  location_y  remaining_min  \
# 0      0            10.0       167.0        72.0           10.0
# 1      1            12.0      -157.0         0.0           10.0
# 2      2            35.0      -101.0       135.0            7.0
# 3      3            43.0       138.0       175.0            6.0
# 4      4           155.0         0.0         0.0            NaN
#
#    power_of_shot  knockout_match game_season  remaining_sec  distance_of_shot  \
# 0            1.0             0.0     2000-01           27.0              38.0
# 1            1.0             0.0     2000-01           22.0              35.0
# 2            1.0             0.0     2000-01           45.0              36.0
# 3            1.0             0.0     2000-01           52.0              42.0
# 4            2.0             0.0     2000-01           19.0              20.0
#
#    is_goal           area_of_shot shot_basics    range_of_shot  \
# ...

# %%
df.is_goal.unique()
# Out:
# array([nan,  0.,  1.])

# %%
pd.value_counts(df.is_goal)
# Out:
# 0.0    13550
# 1.0    10879
# Name: is_goal, dtype: int64

# %%
import numpy as np
df2=df[~np.isfinite(df.is_goal)]
df2
# Out:
#        Index  match_event_id  location_x  location_y  remaining_min  \
# 0          0            10.0       167.0        72.0           10.0
# 7          7           254.0         1.0        28.0            8.0
# 16        16           100.0         0.0         0.0            0.0
# 19        19           249.0         0.0         0.0           10.0
# 21        21           265.0       134.0       127.0            9.0
# 32        32             4.0       163.0        76.0           11.0
# 33        33             8.0        70.0       194.0           10.0
# 34        34            26.0         1.0        19.0            7.0
# 35        35            37.0       -12.0         NaN            5.0
# 36        36            53.0         1.0         4.0            4.0
# 37        37           165.0      -117.0       116.0            5.0
# 44        44           281.0       -12.0        19.0            4.0
# 49        49           410.0      -176.0        30.0            3.0
# ...

# %%
df=df[np.isfinite(df.is_goal)]
df
# Out:
#        Index  match_event_id  location_x  location_y  remaining_min  \
# 1          1            12.0      -157.0         0.0           10.0
# 2          2            35.0      -101.0       135.0            7.0
# 3          3            43.0       138.0       175.0            6.0
# 4          4           155.0         0.0         0.0            NaN
# 5          5           244.0      -145.0       -11.0            9.0
# 6          6           251.0         0.0         0.0            8.0
# 8          8           265.0       -65.0         NaN            6.0
# 9          9           294.0       -33.0         NaN            3.0
# 10        10           309.0       -94.0       238.0            1.0
# 11        11             4.0       121.0       127.0           11.0
# 12        12            27.0       -67.0         NaN            7.0
# 13        13            66.0       -94.0         4.0            NaN
# 14        14            80.0       -23.0        47.0            1.0
# ...

# %%
df2.shot_id_number
# Out:
# 0            1.0
# 7            8.0
# 16           NaN
# 19          20.0
# 21          22.0
# 32          33.0
# 33           NaN
# 34          35.0
# 35          36.0
# 36          37.0
# 37          38.0
# 44          45.0
# 49          50.0
# 54          55.0
# 59          60.0
# 61          62.0
# 65          66.0
# 66          67.0
# 70          71.0
# 71          72.0
# 75          76.0
# 79          80.0
# 84          85.0
# 85          86.0
# 86          87.0
# 91          92.0
# 94          95.0
# 96           NaN
# 103        104.0
# 112        113.0
#           ...
# 30567    30568.0
# 30569    30570.0
# 30580    30581.0
# 30583    30584.0
# 30590    30591.0
# 30593    30594.0
# 30613    30614.0
# 30616    30617.0
# 30617    30618.0
# 30625    30626.0
# 30629    30630.0
# 30630    30631.0
# 30631    30632.0
# 30633    30634.0
# 30635        NaN
# 30636    30637.0
# 30638    30639.0
# 30646    30647.0
# 30648    30649.0
# 30655    30656.0
# 30659    30660.0
# ...

# %%
df2
# Out:
#        Index  match_event_id  location_x  location_y  remaining_min  \
# 0          0            10.0       167.0        72.0           10.0
# 7          7           254.0         1.0        28.0            8.0
# 16        16           100.0         0.0         0.0            0.0
# 19        19           249.0         0.0         0.0           10.0
# 21        21           265.0       134.0       127.0            9.0
# 32        32             4.0       163.0        76.0           11.0
# 33        33             8.0        70.0       194.0           10.0
# 34        34            26.0         1.0        19.0            7.0
# 35        35            37.0       -12.0         NaN            5.0
# 36        36            53.0         1.0         4.0            4.0
# 37        37           165.0      -117.0       116.0            5.0
# 44        44           281.0       -12.0        19.0            4.0
# 49        49           410.0      -176.0        30.0            3.0
# ...

# %%
i=0
while i<6268:
    df2.shot_id_number.iloc[i]=df2.Index.iloc[i]+1
    i=i+1

# %%
df2.shot_id_number
# Out:
# 0            1.0
# 7            8.0
# 16          17.0
# 19          20.0
# 21          22.0
# 32          33.0
# 33          34.0
# 34          35.0
# 35          36.0
# 36          37.0
# 37          38.0
# 44          45.0
# 49          50.0
# 54          55.0
# 59          60.0
# 61          62.0
# 65          66.0
# 66          67.0
# 70          71.0
# 71          72.0
# 75          76.0
# 79          80.0
# 84          85.0
# 85          86.0
# 86          87.0
# 91          92.0
# 94          95.0
# 96          97.0
# 103        104.0
# 112        113.0
#           ...
# 30567    30568.0
# 30569    30570.0
# 30580    30581.0
# 30583    30584.0
# 30590    30591.0
# 30593    30594.0
# 30613    30614.0
# 30616    30617.0
# 30617    30618.0
# 30625    30626.0
# 30629    30630.0
# 30630    30631.0
# 30631    30632.0
# 30633    30634.0
# 30635    30636.0
# 30636    30637.0
# 30638    30639.0
# 30646    30647.0
# 30648    30649.0
# 30655    30656.0
# 30659    30660.0
# ...

# %%
df2[['shot_id_number','is_goal']]
# Out:
#        shot_id_number  is_goal
# 0                 1.0      NaN
# 7                 8.0      NaN
# 16               17.0      NaN
# 19               20.0      NaN
# 21               22.0      NaN
# 32               33.0      NaN
# 33               34.0      NaN
# 34               35.0      NaN
# 35               36.0      NaN
# 36               37.0      NaN
# 37               38.0      NaN
# 44               45.0      NaN
# 49               50.0      NaN
# 54               55.0      NaN
# 59               60.0      NaN
# 61               62.0      NaN
# 65               66.0      NaN
# 66               67.0      NaN
# 70               71.0      NaN
# 71               72.0      NaN
# 75               76.0      NaN
# 79               80.0      NaN
# 84               85.0      NaN
# 85               86.0      NaN
# 86               87.0      NaN
# 91               92.0      NaN
# 94               95.0      NaN
# 96               97.0      NaN
# 103             104.0      NaN
# ...

# %%
df.area_of_shot.unique()
# Out:
# array(['Left Side(L)', 'Left Side Center(LC)', 'Right Side Center(RC)',
#        'Center(C)', 'Right Side(R)', nan, 'Mid Ground(MG)'], dtype=object)

# %%
pd.value_counts(df.area_of_shot)
# Out:
# Center(C)                10177
# Right Side Center(RC)     3616
# Right Side(R)             3504
# Left Side Center(LC)      3031
# Left Side(L)              2848
# Mid Ground(MG)              71
# Name: area_of_shot, dtype: int64

# %%
df.area_of_shot.fillna("Center(C)",inplace=True)

# %%
pd.value_counts(df.area_of_shot)
# Out:
# Center(C)                11359
# Right Side Center(RC)     3616
# Right Side(R)             3504
# Left Side Center(LC)      3031
# Left Side(L)              2848
# Mid Ground(MG)              71
# Name: area_of_shot, dtype: int64

# %%
df.area_of_shot.replace({'Center(C)':1, 'Right Side Center(RC)':2,'Right Side(R)':3,'Left Side Center(LC)':4,'Left Side(L)':5,'Mid Ground(MG)':6},inplace=True)
df.area_of_shot
# Out:
# 1        5
# 2        4
# 3        2
# 4        1
# 5        5
# 6        1
# 8        5
# 9        1
# 10       4
# 11       2
# 12       5
# 13       5
# 14       1
# 15       1
# 17       4
# 18       4
# 20       1
# 22       1
# 23       4
# 24       1
# 25       1
# 26       1
# 27       4
# 28       2
# 29       1
# 30       3
# 31       3
# 38       2
# 39       1
# 40       5
#         ..
# 30657    2
# 30658    1
# 30660    1
# 30661    1
# 30662    1
# 30663    3
# 30665    1
# 30666    4
# 30667    1
# 30669    1
# 30670    1
# 30671    1
# 30672    3
# 30673    3
# 30674    2
# 30675    4
# 30676    5
# 30677    4
# 30678    1
# 30683    1
# 30684    5
# 30685    1
# 30688    5
# 30689    6
# 30690    5
# 30691    1
# 30692    1
# 30694    4
# 30695    1
# 30696    1
# Name: area_of_shot, Length: 24429, dtype: int64

# %%
df.shot_basics.unique()
# Out:
# array(['Mid Range', 'Goal Area', 'Goal Line', 'Penalty Spot', nan,
#        'Right Corner', 'Mid Ground Line', 'Left Corner'], dtype=object)

# %%
pd.value_counts(df.shot_basics)
# Out:
# Mid Range          9488
# Goal Area          5323
# Penalty Spot       4245
# Goal Line          3515
# Right Corner        302
# Left Corner         216
# Mid Ground Line      57
# Name: shot_basics, dtype: int64

# %%
df.shot_basics.fillna("Mid Range",inplace=True)
pd.value_counts(df.shot_basics)
# Out:
# Mid Range          10771
# Goal Area           5323
# Penalty Spot        4245
# Goal Line           3515
# Right Corner         302
# Left Corner          216
# Mid Ground Line       57
# Name: shot_basics, dtype: int64

# %%
df.shot_basics.replace({'Mid Range':1, 'Goal Area':2,'Penalty Spot':3,'Goal Line':4,'Right Corner':5,'Mid Ground Line':6},inplace=True)
df.shot_basics
# Out:
# 1        1
# 2        1
# 3        1
# 4        2
# 5        1
# 6        2
# 8        4
# 9        4
# 10       3
# 11       1
# 12       4
# 13       1
# 14       4
# 15       1
# 17       1
# 18       1
# 20       1
# 22       4
# 23       1
# 24       4
# 25       2
# 26       1
# 27       3
# 28       1
# 29       4
# 30       1
# 31       1
# 38       1
# 39       3
# 40       1
#         ..
# 30657    1
# 30658    1
# 30660    2
# 30661    2
# 30662    4
# 30663    1
# 30665    2
# 30666    1
# 30667    3
# 30669    1
# 30670    4
# 30671    2
# 30672    1
# 30673    1
# 30674    3
# 30675    3
# 30676    1
# 30677    1
# 30678    2
# 30683    1
# 30684    1
# 30685    3
# 30688    1
# 30689    6
# 30690    1
# 30691    2
# 30692    1
# 30694    1
# 30695    3
# 30696    4
# Name: shot_basics, Length: 24429, dtype: object

# %%
df.range_of_shot.unique()
# Out:
# array(['8-16 ft.', '16-24 ft.', 'Less Than 8 ft.', '24+ ft.', nan,
#        'Back Court Shot'], dtype=object)

# %%
pd.value_counts(df.range_of_shot)
# Out:
# Less Than 8 ft.    7064
# 16-24 ft.          6220
# 8-16 ft.           5076
# 24+ ft.            4751
# Back Court Shot      70
# Name: range_of_shot, dtype: int64

# %%
df.range_of_shot.fillna("Less Than 8 ft.",inplace=True)
pd.value_counts(df.range_of_shot)
# Out:
# Less Than 8 ft.    8312
# 16-24 ft.          6220
# 8-16 ft.           5076
# 24+ ft.            4751
# Back Court Shot      70
# Name: range_of_shot, dtype: int64

# %%
df.shot_basics.replace({'Less Than 8 ft.':1, '8-16 ft.':2,'16-24 ft.':3,'24+ ft.':4,'Back Court Shot':5},inplace=True)
df.shot_basics
# Out:
# 1        1
# 2        1
# 3        1
# 4        2
# 5        1
# 6        2
# 8        4
# 9        4
# 10       3
# 11       1
# 12       4
# 13       1
# 14       4
# 15       1
# 17       1
# 18       1
# 20       1
# 22       4
# 23       1
# 24       4
# 25       2
# 26       1
# 27       3
# 28       1
# 29       4
# 30       1
# 31       1
# 38       1
# 39       3
# 40       1
#         ..
# 30657    1
# 30658    1
# 30660    2
# 30661    2
# 30662    4
# 30663    1
# 30665    2
# 30666    1
# 30667    3
# 30669    1
# 30670    4
# 30671    2
# 30672    1
# 30673    1
# 30674    3
# 30675    3
# 30676    1
# 30677    1
# 30678    2
# 30683    1
# 30684    1
# 30685    3
# 30688    1
# 30689    6
# 30690    1
# 30691    2
# 30692    1
# 30694    1
# 30695    3
# 30696    4
# Name: shot_basics, Length: 24429, dtype: object
